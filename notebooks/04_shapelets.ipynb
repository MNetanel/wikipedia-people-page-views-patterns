# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys

src = Path(r'C:\Users\netan\Documents\code\big-data-project\src')
sys.path.append(str(src))
sys.path.append(str(src / 'external_utils' / 'ushapelet_python'))

# from external_utils.ushapelet_python.FindFastUShapelet import FindFastUShapelet
from external_utils.ushapelet_python.SortUshapelets import SortUshapelets
# Out:
# (2, 3137)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 12
#       9 sys.path.append(str(src / 'external_utils' / 'ushapelet_python'))
#      11 # from external_utils.ushapelet_python.FindFastUShapelet import FindFastUShapelet
# ---> 12 from external_utils.ushapelet_python.SortUshapelets import SortUshapelets
#
# File ~\Documents\code\big-data-project\src\external_utils\ushapelet_python\SortUshapelets.py:2
#       1 import numpy as np
# ----> 2 from GetRandomProjectionsMatrix import *
#       4 def SortUshapelets(data, sLen):
#       5     tsNumber, dataWidth = data.shape
#
# File ~\Documents\code\big-data-project\src\external_utils\ushapelet_python\GetRandomProjectionsMatrix.py:91
#      89 views = np.vstack([views1, views2])
#      90 print(views.shape)
# ---> 91 GetRandomProjectionsMatrix(views, 100, 5)
#
# ...

# %%
# Pick an example page
views = pd.read_csv(r'C:\Users\netan\Documents\code\big-data-project\data\pageviews\ABBA.csv')['views']
views = np.expand_dims(views.values, 0)
views
# Out:
# array([[3976, 5455, 5034, ..., 6462, 6008, 5911]], dtype=int64)

# %%
ssts = SortUshapelets(views[:, :500], 50)[1]
ssts
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ssts = SortUshapelets(views[:, :500], 50)[1]
#       2 ssts
#
# File ~\Documents\code\big-data-project\src\external_utils\ushapelet_python\SortUshapelets.py:29, in SortUshapelets(data, sLen)
#      26             zScoredUshapelets[curRow, 2:] = (sub_section - sub_section.mean())/(sub_section.std(ddof=1))
#      27         curRow = curRow + 1
# ---> 29 uShTS = GetRandomProjectionsMatrix(zScoredUshapelets, sLen, sNum)
#      30 SAX_shapelets_TS = np.concatenate((SAX_shapelets_TS, uShTS), axis=1)
#      31 SAX_shapelets_TS_backup = SAX_shapelets_TS
#
# File ~\Documents\code\big-data-project\src\external_utils\ushapelet_python\GetRandomProjectionsMatrix.py:47, in GetRandomProjectionsMatrix(data, sLen, sNum)
#      44     firstInd = firstInd + shStorageVals[i]
# ...

# %%
plt.plot(ssts)

# %%
st = ShapeletTransform().fit()
