# %%
# imports
import numpy as np
import pandas as pd
import polars as pl
from pathlib import Path
from tqdm import tqdm
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import os
import json
import seaborn as sns
from rich import print
import time

load_dotenv()

RAW_DATA_DIR = Path(os.getenv('RAW_DATA_DIR'))
PROCESSED_DATA_DIR = Path(os.getenv('PROCESSED_DATA_DIR'))

# %%
views_df = pl.read_parquet(PROCESSED_DATA_DIR / 'pageviews_all.parquet')
info_df = pl.read_parquet(PROCESSED_DATA_DIR / 'people_data_all.parquet')

# %%
info_df
# Out:
# shape: (1_572_844, 33)
# ┌─────────────┬───────┬───────┬────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ wikidata_co ┆ birth ┆ death ┆ gender ┆ … ┆ count_count ┆ count_educa ┆ count_occup ┆ count_genre │
# │ de          ┆ ---   ┆ ---   ┆ ---    ┆   ┆ ry_of_citiz ┆ ted_at      ┆ ation       ┆ ---         │
# │ ---         ┆ i64   ┆ i64   ┆ str    ┆   ┆ enship      ┆ ---         ┆ ---         ┆ u32         │
# │ str         ┆       ┆       ┆        ┆   ┆ ---         ┆ u32         ┆ u32         ┆             │
# │             ┆       ┆       ┆        ┆   ┆ u32         ┆             ┆             ┆             │
# ╞═════════════╪═══════╪═══════╪════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ Q1000005    ┆ 1860  ┆ 1927  ┆ Male   ┆ … ┆ 1           ┆ 0           ┆ 4           ┆ 0           │
# │ Q100005     ┆ 1922  ┆ 1951  ┆ Male   ┆ … ┆ 1           ┆ 1           ┆ 5           ┆ 0           │
# │ Q1000051    ┆ 1884  ┆ 1962  ┆ Male   ┆ … ┆ 1           ┆ 2           ┆ 3           ┆ 0           │
# │ Q1000053    ┆ 1962  ┆ null  ┆ Male   ┆ … ┆ 2           ┆ 1           ┆ 2           ┆ 0           │
# │ Q1000061    ┆ 1940  ┆ null  ┆ Male   ┆ … ┆ 1           ┆ 1           ┆ 2           ┆ 0           │
# │ …           ┆ …     ┆ …     ┆ …      ┆ … ┆ …           ┆ …           ┆ …           ┆ …           │
# │ Q999994     ┆ 1988  ┆ null  ┆ Male   ┆ … ┆ 1           ┆ 0           ┆ 1           ┆ 0           │
# │ Q999995     ┆ 1987  ┆ null  ┆ Male   ┆ … ┆ 1           ┆ 0           ┆ 1           ┆ 0           │
# │ Q999997     ┆ 1984  ┆ null  ┆ Male   ┆ … ┆ 1           ┆ 0           ┆ 2           ┆ 0           │
# │ Q999998     ┆ 1952  ┆ null  ┆ Male   ┆ … ┆ 1           ┆ 0           ┆ 1           ┆ 0           │
# │ Q999999     ┆ 1982  ┆ null  ┆ Female ┆ … ┆ 1           ┆ 0           ┆ 1           ┆ 0           │
# └─────────────┴───────┴───────┴────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
views_df.drop('title').plot.kde()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 views_df.drop('title').plot.kde(rasterize=True)
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\hvplot\plotting\core.py:1447, in hvPlotTabular.kde(self, y, by, **kwds)
#    1371 def kde(self, y=None, by=None, **kwds):
#    1372     """
#    1373     The Kernel density estimate (`kde`) plot shows the distribution and spread of the data.
#    1374
#    (...)
#    1445     - Wiki: https://en.wikipedia.org/wiki/Kernel_density_estimation
#    1446     """
# -> 1447     return self(kind="kde", x=None, y=y, by=by, **kwds)
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\hvplot\plotting\core.py:96, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      93         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      94         return pn.panel(plot, **panel_dict)
# ---> 96 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\hvplot\converter.py:1275, in HoloViewsConverter.__call__(self, kind, x, y)
#    1272                 dataset = Dataset(data)
#    1273             dataset = dataset.redim(**self._redim)
# -> 1275         obj = method(x, y)
#    1276         obj._dataset = dataset
#    1278 if self.crs and self.project:
#    1279     # Apply projection before rasterizing
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\hvplot\converter.py:1963, in HoloViewsConverter.kde(self, x, y, data)
#    1961 ds = Dataset(df)
#    1962 if len(df):
# -> 1963     dists = ds.to(Distribution, self.value_label)
#    1964     dists = dists.layout() if self.subplots else dists.overlay(sort=False)
#    1965 else:
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\holoviews\core\data\__init__.py:145, in DataConversion.__call__(self, new_type, kdims, vdims, groupby, sort, **kwargs)
#     143     element = new_type(selected, **params)
#     144     return element.sort() if sort else element
# --> 145 group = selected.groupby(groupby, container_type=HoloMap,
#     146                          group_type=new_type, **params)
#     147 if sort:
#     148     return group.map(lambda x: x.sort(), [new_type])
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\holoviews\core\data\__init__.py:196, in PipelineMeta.pipelined.<locals>.pipelined_fn(*args, **kwargs)
#     193     inst._in_method = True
#     195 try:
# --> 196     result = method_fn(*args, **kwargs)
#     197     if PipelineMeta.disable:
#     198         return result
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\holoviews\core\data\__init__.py:1000, in Dataset.groupby(self, dimensions, container_type, group_type, dynamic, **kwargs)
#     996     dynamic_dims = [d.clone(values=list(self.interface.values(self, d.name, False)))
#     997                     for d in dimensions]
#     998     return DynamicMap(load_subset, kdims=dynamic_dims)
# -> 1000 return self.interface.groupby(self, dim_names, container_type,
#    1001                               group_type, **kwargs)
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\holoviews\core\data\pandas.py:238, in PandasInterface.groupby(cls, dataset, dimensions, container_type, group_type, **kwargs)
#     232 if len(group_by) == 1 and util.pandas_version >= Version("1.5.0"):
#     233     # Because of this deprecation warning from pandas 1.5.0:
#     234     # In a future version of pandas, a length 1 tuple will be returned
#     235     # when iterating over a groupby with a grouper equal to a list of length 1.
#     236     # Don't supply a list with a single grouper to avoid this warning.
#     237     group_by = group_by[0]
# --> 238 data = [(k, group_type(v, **group_kwargs)) for k, v in
#     239         dataset.data.groupby(group_by, sort=False)]
#     240 if issubclass(container_type, NdMapping):
#     241     with item_check(False), sorted_context(False):
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\pandas\core\groupby\ops.py:620, in BaseGrouper.get_iterator(self, data, axis)
#     618 splitter = self._get_splitter(data, axis=axis)
#     619 keys = self.group_keys_seq
# --> 620 yield from zip(keys, splitter)
#
# File c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\pandas\core\groupby\ops.py:1157, in DataSplitter.__iter__(self)
#    1152 if self.ngroups == 0:
#    1153     # we are inside a generator, rather than raise StopIteration
#    1154     # we merely return signal the end
#    1155     return
# -> 1157 starts, ends = lib.generate_slices(self._slabels, self.ngroups)
#    1159 for start, end in zip(starts, ends):
#    1160     yield self._chop(sdata, slice(start, end))
#
# KeyboardInterrupt:
