# %%
import numpy as np
import pandas as pd
import polars as pl
from pathlib import Path
from tqdm import tqdm
from functools import reduce
from itertools import product
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
dfs = [pl.read_csv(file) for file in Path(os.getenv('RAW_DATA_DIR')).glob(r'*[0-9].csv')]
len(dfs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48652\3625649387.py in ?()
# ----> 1 dfs = [pl.read_csv(file) for file in Path(os.getenv('RAW_DATA_DIR')).glob(r'*[0-9].csv')]
#       2 len(dfs)
#
# c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\polars\_utils\deprecation.py in ?(*args, **kwargs)
#     130         def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     131             _rename_keyword_argument(
#     132                 old_name, new_name, kwargs, function.__name__, version
#     133             )
# --> 134             return function(*args, **kwargs)
#
# c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\polars\_utils\deprecation.py in ?(*args, **kwargs)
#     130         def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     131             _rename_keyword_argument(
#     132                 old_name, new_name, kwargs, function.__name__, version
#     133             )
# --> 134             return function(*args, **kwargs)
#
# c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\polars\_utils\deprecation.py in ?(*args, **kwargs)
#     130         def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     131             _rename_keyword_argument(
#     132                 old_name, new_name, kwargs, function.__name__, version
#     133             )
# --> 134             return function(*args, **kwargs)
#
# c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\polars\io\csv\functions.py in ?(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines)
#     393         use_pyarrow=False,
#     394         raise_if_empty=raise_if_empty,
#     395         storage_options=storage_options,
#     396     ) as data:
# --> 397         df = pl.DataFrame._read_csv(
#     398             data,
#     399             has_header=has_header,
#     400             columns=columns if columns else projection,
#
# c:\Users\netan\miniconda3\envs\big_data_project\Lib\site-packages\polars\dataframe\frame.py in ?(cls, source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, dtypes, schema, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines)
#     651                 raise ValueError(msg)
#     652
#     653         projection, columns = handle_projection_columns(columns)
#     654
# --> 655         self._df = PyDataFrame.read_csv(
#     656             source,
#     657             infer_schema_length,
#     658             batch_size,
#
# KeyboardInterrupt:

# %%
all_names = pl.concat([df.select('title') for df in dfs]).unique()
print(f'{len(all_names):,}')
# Out:
# 1,976,658

# %%
transformed_dfs = []
for df in tqdm(dfs):
    transformed_df = (df.with_columns(pl.col('month')
                                    .map_elements(lambda s: f'{s[:4]}-{s[5:7]}')
                                    .alias('year_month'))
                      .pivot(index='title', columns='year_month', values='monthly_views')
    )
    transformed_dfs.append(transformed_df)
# Out:
# 100%|██████████| 9/9 [02:05<00:00, 13.89s/it]

# %%
views_df = all_names
for i, df in tqdm(enumerate(transformed_dfs)):
    views_df = df.join(views_df, 'title', 'outer_coalesce')
views_df = views_df.select(['title', *sorted([c for c in views_df.columns if c != 'title'])])
views_df
# Out:
# 9it [00:05,  1.51it/s]
# shape: (1_976_658, 105)
# ┌────────────────────────┬─────────┬─────────┬─────────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ title                  ┆ 2015-05 ┆ 2015-06 ┆ 2015-07 ┆ … ┆ 2023-09 ┆ 2023-10 ┆ 2023-11 ┆ 2023-12 │
# │ ---                    ┆ ---     ┆ ---     ┆ ---     ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str                    ┆ i64     ┆ i64     ┆ i64     ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞════════════════════════╪═════════╪═════════╪═════════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ Neophyte_II_of_Ungro-W ┆ null    ┆ null    ┆ null    ┆ … ┆ 29      ┆ 44      ┆ 23      ┆ 25      │
# │ allachia               ┆         ┆         ┆         ┆   ┆         ┆         ┆         ┆         │
# │ Olivia_Giovetti        ┆ 26      ┆ 34      ┆ 52      ┆ … ┆ 20      ┆ 59      ┆ 41      ┆ 19      │
# │ Alexander_Grant_McLean ┆ 9       ┆ 48      ┆ 24      ┆ … ┆ 9       ┆ 10      ┆ 1       ┆ 5       │
# │ Bernard_H._Raether     ┆ 17      ┆ 16      ┆ 21      ┆ … ┆ 2       ┆ null    ┆ 1       ┆ 2       │
# │ Leigh_Magar            ┆ 47      ┆ 46      ┆ 64      ┆ … ┆ 8       ┆ 5       ┆ 10      ┆ 2       │
# │ …                      ┆ …       ┆ …       ┆ …       ┆ … ┆ …       ┆ …       ┆ …       ┆ …       │
# │ Edgar_Dibden           ┆ null    ┆ null    ┆ null    ┆ … ┆ 6       ┆ 7       ┆ 4       ┆ 2       │
# │ David_Mulready         ┆ 56      ┆ 51      ┆ 78      ┆ … ┆ 14      ┆ 14      ┆ 7       ┆ 6       │
# │ Bruno_Riem             ┆ 40      ┆ 29      ┆ 34      ┆ … ┆ 3       ┆ 3       ┆ 1       ┆ 2       │
# │ Bon_Spence             ┆ 23      ┆ 52      ┆ 38      ┆ … ┆ 10      ┆ 8       ┆ 7       ┆ 6       │
# │ John_Bain_(footballer, ┆ null    ┆ null    ┆ null    ┆ … ┆ 5       ┆ 16      ┆ 8       ┆ 7       │
# │ _born_1923…            ┆         ┆         ┆         ┆   ┆         ┆         ┆         ┆         │
# └────────────────────────┴─────────┴─────────┴─────────┴───┴─────────┴─────────┴─────────┴─────────┘

# %%
views_df.write_parquet('../data/pageviews_all.parquet')

# %%
from typing import Iterable

# %%
def plot_views_by_names(names: Iterable):
    plt.figure(figsize=(20, 3))
    for name in names:
        try:
            x = views_df.select(pl.exclude('title')).columns
            y = views_df.filter(pl.col('title') == name).select(pl.exclude('title')).to_numpy().ravel()
            plt.plot(x, y, label=name)
        except:
            print(f'{name} not found.')
            continue
    plt.legend()
    plt.xticks(rotation=-90)
    plt.show();

# %%
plot_views_by_names(['John_Lennon', 'Ringo_Starr', 'Dan_Avidan', 'Arin_Hanson'])
